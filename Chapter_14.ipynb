# %%
[A] State whether the following statements are True or False: 
(a) Inheritance is the ability for a class to inherit properties and behavior from a parent class by extending it. 
Ans: True

(b) Containership is the ability of a class to contain objects of different classes as member data. 
Ans: True

(c) We can derive a class from a base class even if the base class's source code is not available. 
Ans: False

(d) Multiple inheritance is different from multiple levels of inheritance.
Ans: 


(e) An object of a derived class cannot access members of base class is the member names begin with_. 
Ans: False

(f) Creating a derived class from a base class requires fundamental changes to the base class. 


(g) If a base class contains a member function func( ), and a derived class does not contain a function with this name, 
an object of the derived class cannot access func( ). 
Ans:False


(h) If no constructors are specified for a derived class, 
objects of the derived class will use the constructors in the base class. 
Ans:True


(i) If a base class and a derived class each include a member function with the same name, 
the member function of the derived class will be called by an object of the derived class. 
Ans: True

(j) A class D can be derived from a class C, which is derived from a class B, which is derived from a class A.
Ans:True


(k) It is illegal to make objects of one class members of another class. 
Ans: False


[B] Answer the following: 
(a) Which module should be imported to create abstract class? 
Ans: @


(b) For a class to be abstract from which class should we inherit it? 
Ans:No


#(c)   Implement a String class containing the following functions: 
#    - Overloaded += operator function to perform string concatenation. 
#    - Method to Lower( ) to convert upper case letters to lower case. 
#    - Method to Upper( ) to convert lower case letters to upper case. 

Ans: class Strg1:
    def __iadd__(self,a,b):
        self.a = a
        self.b = b
    def add(self):
        self.a = 'a'
        self.b = 'b'
        c = self.a + self.b
        print(c.lower())
        print(c.upper())
        print(c)
    

d = Strg1()
e = d.add()
print(e)


# (d)Suppose there is a base class B and a derived class D derived from B. 
    #B has two public member functions b1( ) and b2( ), 
    #whereas D has two member functions d1( ) and d2( ). 
    #Write these classes for the following different situations: 
    #- b1( ) should be accessible from main module, b2( ) should not be.
    #- Neither b1( ), nor b2( ) should be accessible from main module. 
    #- Both b1( ) and b2( ) should be accessible from main module.
    
Ans:
    class Base:
    def __init__(self,b1,__b2):
        self.b1 = b1
        self.__b2 = __b2
    
class Derived(Base):
    def d1():
        print('printed D1')
    def d2():
        print('printed D2')
        
x = Derived(8,9)
print(x.b1)
print(x.__b2)

    
(e) If a class D is derived from two base classes B1 and B2, then write these classes each containing a constructor.
Ensure that while building an object of type D, constructor of B2 should get called. Also provide a destructor in each class. 
In what order would these destructors get called? 




(f) Create an abstract class called Vehicle containing methods speed( ), maintenance( ) and value( ) in it. 
Derive classes FourWheeler, TwoWheeler and Airborne from Vehicle class. Check whether you are able to prevent creation of 
objects of Vehicle class. Call the methods using objects of other classes. 




#(g) Assume a class D that is derived from class B. Which of the following can an object of class D access?
#- members of D
#- members of B
Ans: Ans: members of B

# %%
#(e) If a class D is derived from two base classes B1 and B2, 
#    then write these classes each containing a constructor.
#    Ensure that while building an object of type D, 
#    constructor of B2 should get called. 
#    Also provide a destructor in each class. 
#    In what order would these destructors get called? 


class B1:
    pass
    
class B2:
    def __init__(self,a):
    
    def add(self):
        a = self.a + self.a
        
    def sub(self):
        a = self.a + self.a

class D(B2):
    def __init__(self):
        super().__init__()

m = D(2)
print(m.add())
# Out:
#   File "<ipython-input-3-93247f1b0a16>", line 15
#     def add(self):
#       ^
# IndentationError: expected an indented block

# %%
#(f) Create an abstract class called Vehicle containing methods speed( ), maintenance( ) and value( ) in it. 
#Derive classes FourWheeler, TwoWheeler and Airborne from Vehicle class. 
#Check whether you are able to prevent creation of objects of Vehicle class. 
#Call the methods using objects of other classes. 


class Vehicle:
    def __init__(self,x,y):
        self.x = x
        self.y = y
        
    def speed(self):
        self.x = '100'
        self.y = 'kmph'
        c = self.x + self.y
        print(c)
        
    def maintenance(self):
        self.x = '12jun'
        self.y = '2019'
        c = self.x + self.y
        print(c)
        
    def value(self):
        self.x = 200
        self.y = 250
        c = self.x + self.y
        print(c)
        
class FourWheeler(Vehicle):
    def __init__(self):
        super().__init__()
    
class TwoWheeler(Vehicle):
    def __init__(self):
        super().__init__()
class Airborne(Vehicle):
    def __init__(self):
        super().__init__()
        
#a = FourWheeler(1,2,3)
b = TwoWheeler(3)
c = Airborne()
print(b.mainenance())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-ce5779892870> in <module>
#      39
#      40
# ---> 41 a = FourWheeler(1,2)
#      42 #b = TwoWheeler(3)
#      43 #c = Airborne()
#
# TypeError: __init__() takes 1 positional argument but 3 were given
